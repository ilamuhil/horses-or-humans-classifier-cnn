# %% [markdown]
# ### Section is to identify whether the image is a horse or a human.
# - images are colored. Extract real images and need to be converted to 3D matrices

# %%
import zipfile
import sys
import warnings
import os
import h5py
import numpy as np
import joblib as j
from tensorflow.keras import Model
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import Sequential,load_model
from tensorflow.keras.layers import Dense, MaxPooling2D, Conv2D,Flatten, Dropout
from tensorflow.keras.optimizers.legacy import RMSprop
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.inception_v3 import InceptionV3
from tensorflow.keras.callbacks import EarlyStopping,ModelCheckpoint
warnings.filterwarnings('ignore')

# %% [markdown]
# #### Extracting the training and validation set into their respective directories

# %%
train_file_name, validation_file_name = "horse-or-human.zip", "validation-horse-or-human.zip"
training_dir,validation_dir = 'horse-or-human/training/','horse-or-human/validation/'
RETRAIN_model1 = True ## model1 is a custom nueral network built from scratch. If retrain = False the model will be loaded from memory (custom_best_model.h5)
RETRAIN_model2 = True ## model2 is a an image classifier that is an extension of InceptionV3 model. If retrain = True the model will be trained on the dataset else it will load the best parameters from memory (pretrained_best_model.h5)
with zipfile.ZipFile(train_file_name, 'r') as train_zipref:
    train_zipref.extractall(training_dir)

with zipfile.ZipFile(validation_file_name, 'r') as validation_zipref:
    validation_zipref.extractall(validation_dir)

# %% [markdown]
# #### We use image Augmentation techniques for improved Accuracy
# - We also define callbacks on models for stopping training the model with poor accuracy metrics

# %%
early_stopping_callback = EarlyStopping(patience=5,monitor='val_loss',verbose=1,mode='min')
model_checkpoint_callback_custom = ModelCheckpoint('custom_best_model.h5', monitor='val_loss', save_best_only=True,verbose=1, save_freq='epoch')
model_checkpoint_callback_pretrained = ModelCheckpoint('pretrained_best_model.h5', monitor='val_loss', save_best_only=True,verbose=1, save_freq='epoch')

# %%
train_data_gen,validation_data_gen = ImageDataGenerator(rescale=1./255,rotation_range=35,width_shift_range=0.1,height_shift_range=.25,shear_range=0.2,zoom_range=0.2,horizontal_flip=True,fill_mode='nearest'),ImageDataGenerator(rescale=1./255,rotation_range=35,width_shift_range=0.1,height_shift_range=.25,shear_range=0.2,zoom_range=0.2,horizontal_flip=True,fill_mode='nearest')
train_generator,validation_generator = train_data_gen.flow_from_directory(training_dir,target_size=(300,300),class_mode='binary'),validation_data_gen.flow_from_directory(validation_dir,target_size=(300,300),class_mode='binary')
# Out:
# Found 1027 images belonging to 2 classes.
# Found 256 images belonging to 2 classes.

# %%
model = Sequential([
  Conv2D(16,(3,3),input_shape=(300,300,3),activation='relu'),
  MaxPooling2D(2,2),
  Conv2D(32,(3,3), activation='relu'),
  MaxPooling2D(2,2),
  Conv2D(64,(3,3), activation='relu'),
  MaxPooling2D(2,2),
  Conv2D(64,(3,3), activation='relu'),
  MaxPooling2D(2,2),
  Conv2D(64,(3,3), activation='relu'),
  MaxPooling2D(2,2),
  Flatten(),
  Dense(512,activation='relu'),
  Dropout(0.2),
  Dense(1,activation='sigmoid')
])

model.compile(loss='binary_crossentropy',optimizer=RMSprop(learning_rate=0.001),metrics=['accuracy'])

# %%
if((RETRAIN_model1) or (not os.path.exists('custom_best_model.h5'))):
  history = model.fit(train_generator,epochs=15,validation_data=validation_generator,callbacks=[early_stopping_callback,model_checkpoint_callback_custom]) 
else :
  model = load_model('custom_best_model.h5')
  print("Best model loaded from memory.")
# Out:
# Best model loaded from memory.

# %% [markdown]
# #### Testing some real images with the trained model
# - Even though the validation accuracy is moderate the classification is very 100% accurate on the test_images

# %%
file_name = "./inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5"
if not os.path.isfile(file_name):
    print("File not found:", file_name)
    sys.exit("Execution stopped because the file was not found")
else:
    print("File exists.")
    
try:
    with h5py.File(file_name, 'r') as f:
        print("File is a valid HDF5 file.")
except OSError as e:
    print("File is not a valid HDF5 file.",e,)
    sys.exit("File was corrupted or of an invalid format")
# Out:
# File exists.
# File is a valid HDF5 file.

# %%
file_name = "./inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5"
pretrained_model = InceptionV3(input_shape=(300,300,3),include_top=False,weights=None)
pretrained_model.load_weights(file_name)
pretrained_model.summary()
# Out:
# Model: "inception_v3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 300, 300, 3  0           []
#                                 )]
#
#  conv2d_5 (Conv2D)              (None, 149, 149, 32  864         ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 149, 149, 32  96         ['conv2d_5[0][0]']
#  alization)                     )
#
#  activation (Activation)        (None, 149, 149, 32  0           ['batch_normalization[0][0]']
#                                 )
#
#  conv2d_6 (Conv2D)              (None, 147, 147, 32  9216        ['activation[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 147, 147, 32  96         ['conv2d_6[0][0]']
#  rmalization)                   )
#
#  activation_1 (Activation)      (None, 147, 147, 32  0           ['batch_normalization_1[0][0]']
#                                 )
#
#  conv2d_7 (Conv2D)              (None, 147, 147, 64  18432       ['activation_1[0][0]']
#                                 )
#
#  batch_normalization_2 (BatchNo  (None, 147, 147, 64  192        ['conv2d_7[0][0]']
#  rmalization)                   )
#
#  activation_2 (Activation)      (None, 147, 147, 64  0           ['batch_normalization_2[0][0]']
#                                 )
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 73, 73, 64)  0           ['activation_2[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 73, 73, 80)   5120        ['max_pooling2d_5[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 73, 73, 80)  240         ['conv2d_8[0][0]']
#  rmalization)
#
#  activation_3 (Activation)      (None, 73, 73, 80)   0           ['batch_normalization_3[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 71, 71, 192)  138240      ['activation_3[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 71, 71, 192)  576        ['conv2d_9[0][0]']
#  rmalization)
#
#  activation_4 (Activation)      (None, 71, 71, 192)  0           ['batch_normalization_4[0][0]']
#
#  max_pooling2d_6 (MaxPooling2D)  (None, 35, 35, 192)  0          ['activation_4[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 35, 35, 64)   12288       ['max_pooling2d_6[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 35, 35, 64)  192         ['conv2d_13[0][0]']
#  rmalization)
#
#  activation_8 (Activation)      (None, 35, 35, 64)   0           ['batch_normalization_8[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 35, 35, 48)   9216        ['max_pooling2d_6[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 35, 35, 96)   55296       ['activation_8[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 35, 35, 48)  144         ['conv2d_11[0][0]']
#  rmalization)
#
#  batch_normalization_9 (BatchNo  (None, 35, 35, 96)  288         ['conv2d_14[0][0]']
#  rmalization)
#
#  activation_6 (Activation)      (None, 35, 35, 48)   0           ['batch_normalization_6[0][0]']
#
#  activation_9 (Activation)      (None, 35, 35, 96)   0           ['batch_normalization_9[0][0]']
#
#  average_pooling2d (AveragePool  (None, 35, 35, 192)  0          ['max_pooling2d_6[0][0]']
#  ing2D)
#
#  conv2d_10 (Conv2D)             (None, 35, 35, 64)   12288       ['max_pooling2d_6[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 35, 35, 64)   76800       ['activation_6[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 35, 35, 96)   82944       ['activation_9[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 35, 35, 32)   6144        ['average_pooling2d[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 35, 35, 64)  192         ['conv2d_10[0][0]']
#  rmalization)
#
#  batch_normalization_7 (BatchNo  (None, 35, 35, 64)  192         ['conv2d_12[0][0]']
#  rmalization)
#
#  batch_normalization_10 (BatchN  (None, 35, 35, 96)  288         ['conv2d_15[0][0]']
#  ormalization)
#
#  batch_normalization_11 (BatchN  (None, 35, 35, 32)  96          ['conv2d_16[0][0]']
#  ormalization)
#
#  activation_5 (Activation)      (None, 35, 35, 64)   0           ['batch_normalization_5[0][0]']
#
#  activation_7 (Activation)      (None, 35, 35, 64)   0           ['batch_normalization_7[0][0]']
#
#  activation_10 (Activation)     (None, 35, 35, 96)   0           ['batch_normalization_10[0][0]']
#
#  activation_11 (Activation)     (None, 35, 35, 32)   0           ['batch_normalization_11[0][0]']
#
#  mixed0 (Concatenate)           (None, 35, 35, 256)  0           ['activation_5[0][0]',
#                                                                   'activation_7[0][0]',
#                                                                   'activation_10[0][0]',
#                                                                   'activation_11[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 35, 35, 64)   16384       ['mixed0[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 35, 35, 64)  192         ['conv2d_20[0][0]']
#  ormalization)
#
#  activation_15 (Activation)     (None, 35, 35, 64)   0           ['batch_normalization_15[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 35, 35, 48)   12288       ['mixed0[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 35, 35, 96)   55296       ['activation_15[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 35, 35, 48)  144         ['conv2d_18[0][0]']
#  ormalization)
#
#  batch_normalization_16 (BatchN  (None, 35, 35, 96)  288         ['conv2d_21[0][0]']
#  ormalization)
#
#  activation_13 (Activation)     (None, 35, 35, 48)   0           ['batch_normalization_13[0][0]']
#
#  activation_16 (Activation)     (None, 35, 35, 96)   0           ['batch_normalization_16[0][0]']
#
#  average_pooling2d_1 (AveragePo  (None, 35, 35, 256)  0          ['mixed0[0][0]']
#  oling2D)
#
#  conv2d_17 (Conv2D)             (None, 35, 35, 64)   16384       ['mixed0[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 35, 35, 64)   76800       ['activation_13[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 35, 35, 96)   82944       ['activation_16[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 35, 35, 64)   16384       ['average_pooling2d_1[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 35, 35, 64)  192         ['conv2d_17[0][0]']
#  ormalization)
#
#  batch_normalization_14 (BatchN  (None, 35, 35, 64)  192         ['conv2d_19[0][0]']
#  ormalization)
#
#  batch_normalization_17 (BatchN  (None, 35, 35, 96)  288         ['conv2d_22[0][0]']
#  ormalization)
#
#  batch_normalization_18 (BatchN  (None, 35, 35, 64)  192         ['conv2d_23[0][0]']
#  ormalization)
#
#  activation_12 (Activation)     (None, 35, 35, 64)   0           ['batch_normalization_12[0][0]']
#
#  activation_14 (Activation)     (None, 35, 35, 64)   0           ['batch_normalization_14[0][0]']
#
#  activation_17 (Activation)     (None, 35, 35, 96)   0           ['batch_normalization_17[0][0]']
#
#  activation_18 (Activation)     (None, 35, 35, 64)   0           ['batch_normalization_18[0][0]']
#
#  mixed1 (Concatenate)           (None, 35, 35, 288)  0           ['activation_12[0][0]',
#                                                                   'activation_14[0][0]',
#                                                                   'activation_17[0][0]',
#                                                                   'activation_18[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 35, 35, 64)   18432       ['mixed1[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 35, 35, 64)  192         ['conv2d_27[0][0]']
#  ormalization)
#
#  activation_22 (Activation)     (None, 35, 35, 64)   0           ['batch_normalization_22[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 35, 35, 48)   13824       ['mixed1[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 35, 35, 96)   55296       ['activation_22[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 35, 35, 48)  144         ['conv2d_25[0][0]']
#  ormalization)
#
#  batch_normalization_23 (BatchN  (None, 35, 35, 96)  288         ['conv2d_28[0][0]']
#  ormalization)
#
#  activation_20 (Activation)     (None, 35, 35, 48)   0           ['batch_normalization_20[0][0]']
#
#  activation_23 (Activation)     (None, 35, 35, 96)   0           ['batch_normalization_23[0][0]']
#
#  average_pooling2d_2 (AveragePo  (None, 35, 35, 288)  0          ['mixed1[0][0]']
#  oling2D)
#
#  conv2d_24 (Conv2D)             (None, 35, 35, 64)   18432       ['mixed1[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 35, 35, 64)   76800       ['activation_20[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 35, 35, 96)   82944       ['activation_23[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 35, 35, 64)   18432       ['average_pooling2d_2[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 35, 35, 64)  192         ['conv2d_24[0][0]']
#  ormalization)
#
#  batch_normalization_21 (BatchN  (None, 35, 35, 64)  192         ['conv2d_26[0][0]']
#  ormalization)
#
#  batch_normalization_24 (BatchN  (None, 35, 35, 96)  288         ['conv2d_29[0][0]']
#  ormalization)
#
#  batch_normalization_25 (BatchN  (None, 35, 35, 64)  192         ['conv2d_30[0][0]']
#  ormalization)
#
#  activation_19 (Activation)     (None, 35, 35, 64)   0           ['batch_normalization_19[0][0]']
#
#  activation_21 (Activation)     (None, 35, 35, 64)   0           ['batch_normalization_21[0][0]']
#
#  activation_24 (Activation)     (None, 35, 35, 96)   0           ['batch_normalization_24[0][0]']
#
#  activation_25 (Activation)     (None, 35, 35, 64)   0           ['batch_normalization_25[0][0]']
#
#  mixed2 (Concatenate)           (None, 35, 35, 288)  0           ['activation_19[0][0]',
#                                                                   'activation_21[0][0]',
#                                                                   'activation_24[0][0]',
#                                                                   'activation_25[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 35, 35, 64)   18432       ['mixed2[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 35, 35, 64)  192         ['conv2d_32[0][0]']
#  ormalization)
#
#  activation_27 (Activation)     (None, 35, 35, 64)   0           ['batch_normalization_27[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 35, 35, 96)   55296       ['activation_27[0][0]']
#
#  batch_normalization_28 (BatchN  (None, 35, 35, 96)  288         ['conv2d_33[0][0]']
#  ormalization)
#
#  activation_28 (Activation)     (None, 35, 35, 96)   0           ['batch_normalization_28[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 17, 17, 384)  995328      ['mixed2[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 17, 17, 96)   82944       ['activation_28[0][0]']
#
#  batch_normalization_26 (BatchN  (None, 17, 17, 384)  1152       ['conv2d_31[0][0]']
#  ormalization)
#
#  batch_normalization_29 (BatchN  (None, 17, 17, 96)  288         ['conv2d_34[0][0]']
#  ormalization)
#
#  activation_26 (Activation)     (None, 17, 17, 384)  0           ['batch_normalization_26[0][0]']
#
#  activation_29 (Activation)     (None, 17, 17, 96)   0           ['batch_normalization_29[0][0]']
#
#  max_pooling2d_7 (MaxPooling2D)  (None, 17, 17, 288)  0          ['mixed2[0][0]']
#
#  mixed3 (Concatenate)           (None, 17, 17, 768)  0           ['activation_26[0][0]',
#                                                                   'activation_29[0][0]',
#                                                                   'max_pooling2d_7[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 17, 17, 128)  98304       ['mixed3[0][0]']
#
#  batch_normalization_34 (BatchN  (None, 17, 17, 128)  384        ['conv2d_39[0][0]']
#  ormalization)
#
#  activation_34 (Activation)     (None, 17, 17, 128)  0           ['batch_normalization_34[0][0]']
#
#  conv2d_40 (Conv2D)             (None, 17, 17, 128)  114688      ['activation_34[0][0]']
#
#  batch_normalization_35 (BatchN  (None, 17, 17, 128)  384        ['conv2d_40[0][0]']
#  ormalization)
#
#  activation_35 (Activation)     (None, 17, 17, 128)  0           ['batch_normalization_35[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 17, 17, 128)  98304       ['mixed3[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 17, 17, 128)  114688      ['activation_35[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 17, 17, 128)  384        ['conv2d_36[0][0]']
#  ormalization)
#
#  batch_normalization_36 (BatchN  (None, 17, 17, 128)  384        ['conv2d_41[0][0]']
#  ormalization)
#
#  activation_31 (Activation)     (None, 17, 17, 128)  0           ['batch_normalization_31[0][0]']
#
#  activation_36 (Activation)     (None, 17, 17, 128)  0           ['batch_normalization_36[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 17, 17, 128)  114688      ['activation_31[0][0]']
#
#  conv2d_42 (Conv2D)             (None, 17, 17, 128)  114688      ['activation_36[0][0]']
#
#  batch_normalization_32 (BatchN  (None, 17, 17, 128)  384        ['conv2d_37[0][0]']
#  ormalization)
#
#  batch_normalization_37 (BatchN  (None, 17, 17, 128)  384        ['conv2d_42[0][0]']
#  ormalization)
#
#  activation_32 (Activation)     (None, 17, 17, 128)  0           ['batch_normalization_32[0][0]']
#
#  activation_37 (Activation)     (None, 17, 17, 128)  0           ['batch_normalization_37[0][0]']
#
#  average_pooling2d_3 (AveragePo  (None, 17, 17, 768)  0          ['mixed3[0][0]']
#  oling2D)
#
#  conv2d_35 (Conv2D)             (None, 17, 17, 192)  147456      ['mixed3[0][0]']
#
#  conv2d_38 (Conv2D)             (None, 17, 17, 192)  172032      ['activation_32[0][0]']
#
#  conv2d_43 (Conv2D)             (None, 17, 17, 192)  172032      ['activation_37[0][0]']
#
#  conv2d_44 (Conv2D)             (None, 17, 17, 192)  147456      ['average_pooling2d_3[0][0]']
#
#  batch_normalization_30 (BatchN  (None, 17, 17, 192)  576        ['conv2d_35[0][0]']
#  ormalization)
#
#  batch_normalization_33 (BatchN  (None, 17, 17, 192)  576        ['conv2d_38[0][0]']
#  ormalization)
#
#  batch_normalization_38 (BatchN  (None, 17, 17, 192)  576        ['conv2d_43[0][0]']
#  ormalization)
#
#  batch_normalization_39 (BatchN  (None, 17, 17, 192)  576        ['conv2d_44[0][0]']
#  ormalization)
#
#  activation_30 (Activation)     (None, 17, 17, 192)  0           ['batch_normalization_30[0][0]']
#
#  activation_33 (Activation)     (None, 17, 17, 192)  0           ['batch_normalization_33[0][0]']
#
#  activation_38 (Activation)     (None, 17, 17, 192)  0           ['batch_normalization_38[0][0]']
#
#  activation_39 (Activation)     (None, 17, 17, 192)  0           ['batch_normalization_39[0][0]']
#
#  mixed4 (Concatenate)           (None, 17, 17, 768)  0           ['activation_30[0][0]',
#                                                                   'activation_33[0][0]',
#                                                                   'activation_38[0][0]',
#                                                                   'activation_39[0][0]']
#
#  conv2d_49 (Conv2D)             (None, 17, 17, 160)  122880      ['mixed4[0][0]']
#
#  batch_normalization_44 (BatchN  (None, 17, 17, 160)  480        ['conv2d_49[0][0]']
#  ormalization)
#
#  activation_44 (Activation)     (None, 17, 17, 160)  0           ['batch_normalization_44[0][0]']
#
#  conv2d_50 (Conv2D)             (None, 17, 17, 160)  179200      ['activation_44[0][0]']
#
#  batch_normalization_45 (BatchN  (None, 17, 17, 160)  480        ['conv2d_50[0][0]']
#  ormalization)
#
#  activation_45 (Activation)     (None, 17, 17, 160)  0           ['batch_normalization_45[0][0]']
#
#  conv2d_46 (Conv2D)             (None, 17, 17, 160)  122880      ['mixed4[0][0]']
#
#  conv2d_51 (Conv2D)             (None, 17, 17, 160)  179200      ['activation_45[0][0]']
#
#  batch_normalization_41 (BatchN  (None, 17, 17, 160)  480        ['conv2d_46[0][0]']
#  ormalization)
#
#  batch_normalization_46 (BatchN  (None, 17, 17, 160)  480        ['conv2d_51[0][0]']
#  ormalization)
#
#  activation_41 (Activation)     (None, 17, 17, 160)  0           ['batch_normalization_41[0][0]']
#
#  activation_46 (Activation)     (None, 17, 17, 160)  0           ['batch_normalization_46[0][0]']
#
#  conv2d_47 (Conv2D)             (None, 17, 17, 160)  179200      ['activation_41[0][0]']
#
#  conv2d_52 (Conv2D)             (None, 17, 17, 160)  179200      ['activation_46[0][0]']
#
#  batch_normalization_42 (BatchN  (None, 17, 17, 160)  480        ['conv2d_47[0][0]']
#  ormalization)
#
#  batch_normalization_47 (BatchN  (None, 17, 17, 160)  480        ['conv2d_52[0][0]']
#  ormalization)
#
#  activation_42 (Activation)     (None, 17, 17, 160)  0           ['batch_normalization_42[0][0]']
#
#  activation_47 (Activation)     (None, 17, 17, 160)  0           ['batch_normalization_47[0][0]']
#
#  average_pooling2d_4 (AveragePo  (None, 17, 17, 768)  0          ['mixed4[0][0]']
#  oling2D)
#
#  conv2d_45 (Conv2D)             (None, 17, 17, 192)  147456      ['mixed4[0][0]']
#
#  conv2d_48 (Conv2D)             (None, 17, 17, 192)  215040      ['activation_42[0][0]']
#
#  conv2d_53 (Conv2D)             (None, 17, 17, 192)  215040      ['activation_47[0][0]']
#
#  conv2d_54 (Conv2D)             (None, 17, 17, 192)  147456      ['average_pooling2d_4[0][0]']
#
#  batch_normalization_40 (BatchN  (None, 17, 17, 192)  576        ['conv2d_45[0][0]']
#  ormalization)
#
#  batch_normalization_43 (BatchN  (None, 17, 17, 192)  576        ['conv2d_48[0][0]']
#  ormalization)
#
#  batch_normalization_48 (BatchN  (None, 17, 17, 192)  576        ['conv2d_53[0][0]']
#  ormalization)
#
#  batch_normalization_49 (BatchN  (None, 17, 17, 192)  576        ['conv2d_54[0][0]']
#  ormalization)
#
#  activation_40 (Activation)     (None, 17, 17, 192)  0           ['batch_normalization_40[0][0]']
#
#  activation_43 (Activation)     (None, 17, 17, 192)  0           ['batch_normalization_43[0][0]']
#
#  activation_48 (Activation)     (None, 17, 17, 192)  0           ['batch_normalization_48[0][0]']
#
#  activation_49 (Activation)     (None, 17, 17, 192)  0           ['batch_normalization_49[0][0]']
#
#  mixed5 (Concatenate)           (None, 17, 17, 768)  0           ['activation_40[0][0]',
#                                                                   'activation_43[0][0]',
#                                                                   'activation_48[0][0]',
#                                                                   'activation_49[0][0]']
#
#  conv2d_59 (Conv2D)             (None, 17, 17, 160)  122880      ['mixed5[0][0]']
#
#  batch_normalization_54 (BatchN  (None, 17, 17, 160)  480        ['conv2d_59[0][0]']
#  ormalization)
#
#  activation_54 (Activation)     (None, 17, 17, 160)  0           ['batch_normalization_54[0][0]']
#
#  conv2d_60 (Conv2D)             (None, 17, 17, 160)  179200      ['activation_54[0][0]']
#
#  batch_normalization_55 (BatchN  (None, 17, 17, 160)  480        ['conv2d_60[0][0]']
#  ormalization)
#
#  activation_55 (Activation)     (None, 17, 17, 160)  0           ['batch_normalization_55[0][0]']
#
#  conv2d_56 (Conv2D)             (None, 17, 17, 160)  122880      ['mixed5[0][0]']
#
#  conv2d_61 (Conv2D)             (None, 17, 17, 160)  179200      ['activation_55[0][0]']
#
#  batch_normalization_51 (BatchN  (None, 17, 17, 160)  480        ['conv2d_56[0][0]']
#  ormalization)
#
#  batch_normalization_56 (BatchN  (None, 17, 17, 160)  480        ['conv2d_61[0][0]']
#  ormalization)
#
#  activation_51 (Activation)     (None, 17, 17, 160)  0           ['batch_normalization_51[0][0]']
#
#  activation_56 (Activation)     (None, 17, 17, 160)  0           ['batch_normalization_56[0][0]']
#
#  conv2d_57 (Conv2D)             (None, 17, 17, 160)  179200      ['activation_51[0][0]']
#
#  conv2d_62 (Conv2D)             (None, 17, 17, 160)  179200      ['activation_56[0][0]']
#
#  batch_normalization_52 (BatchN  (None, 17, 17, 160)  480        ['conv2d_57[0][0]']
#  ormalization)
#
#  batch_normalization_57 (BatchN  (None, 17, 17, 160)  480        ['conv2d_62[0][0]']
#  ormalization)
#
#  activation_52 (Activation)     (None, 17, 17, 160)  0           ['batch_normalization_52[0][0]']
#
#  activation_57 (Activation)     (None, 17, 17, 160)  0           ['batch_normalization_57[0][0]']
#
#  average_pooling2d_5 (AveragePo  (None, 17, 17, 768)  0          ['mixed5[0][0]']
#  oling2D)
#
#  conv2d_55 (Conv2D)             (None, 17, 17, 192)  147456      ['mixed5[0][0]']
#
#  conv2d_58 (Conv2D)             (None, 17, 17, 192)  215040      ['activation_52[0][0]']
#
#  conv2d_63 (Conv2D)             (None, 17, 17, 192)  215040      ['activation_57[0][0]']
#
#  conv2d_64 (Conv2D)             (None, 17, 17, 192)  147456      ['average_pooling2d_5[0][0]']
#
#  batch_normalization_50 (BatchN  (None, 17, 17, 192)  576        ['conv2d_55[0][0]']
#  ormalization)
#
#  batch_normalization_53 (BatchN  (None, 17, 17, 192)  576        ['conv2d_58[0][0]']
#  ormalization)
#
#  batch_normalization_58 (BatchN  (None, 17, 17, 192)  576        ['conv2d_63[0][0]']
#  ormalization)
#
#  batch_normalization_59 (BatchN  (None, 17, 17, 192)  576        ['conv2d_64[0][0]']
#  ormalization)
#
#  activation_50 (Activation)     (None, 17, 17, 192)  0           ['batch_normalization_50[0][0]']
#
#  activation_53 (Activation)     (None, 17, 17, 192)  0           ['batch_normalization_53[0][0]']
#
#  activation_58 (Activation)     (None, 17, 17, 192)  0           ['batch_normalization_58[0][0]']
#
#  activation_59 (Activation)     (None, 17, 17, 192)  0           ['batch_normalization_59[0][0]']
# ...
#  mixed8 (Concatenate)           (None, 8, 8, 1280)   0           ['activation_71[0][0]',
#                                                                   'activation_75[0][0]',
#                                                                   'max_pooling2d_8[0][0]']
#
#  conv2d_85 (Conv2D)             (None, 8, 8, 448)    573440      ['mixed8[0][0]']
#
#  batch_normalization_80 (BatchN  (None, 8, 8, 448)   1344        ['conv2d_85[0][0]']
#  ormalization)
#
#  activation_80 (Activation)     (None, 8, 8, 448)    0           ['batch_normalization_80[0][0]']
#
#  conv2d_82 (Conv2D)             (None, 8, 8, 384)    491520      ['mixed8[0][0]']
#
#  conv2d_86 (Conv2D)             (None, 8, 8, 384)    1548288     ['activation_80[0][0]']
#
#  batch_normalization_77 (BatchN  (None, 8, 8, 384)   1152        ['conv2d_82[0][0]']
#  ormalization)
#
#  batch_normalization_81 (BatchN  (None, 8, 8, 384)   1152        ['conv2d_86[0][0]']
#  ormalization)
#
#  activation_77 (Activation)     (None, 8, 8, 384)    0           ['batch_normalization_77[0][0]']
#
#  activation_81 (Activation)     (None, 8, 8, 384)    0           ['batch_normalization_81[0][0]']
#
#  conv2d_83 (Conv2D)             (None, 8, 8, 384)    442368      ['activation_77[0][0]']
#
#  conv2d_84 (Conv2D)             (None, 8, 8, 384)    442368      ['activation_77[0][0]']
#
#  conv2d_87 (Conv2D)             (None, 8, 8, 384)    442368      ['activation_81[0][0]']
#
#  conv2d_88 (Conv2D)             (None, 8, 8, 384)    442368      ['activation_81[0][0]']
#
#  average_pooling2d_7 (AveragePo  (None, 8, 8, 1280)  0           ['mixed8[0][0]']
#  oling2D)
#
#  conv2d_81 (Conv2D)             (None, 8, 8, 320)    409600      ['mixed8[0][0]']
#
#  batch_normalization_78 (BatchN  (None, 8, 8, 384)   1152        ['conv2d_83[0][0]']
#  ormalization)
#
#  batch_normalization_79 (BatchN  (None, 8, 8, 384)   1152        ['conv2d_84[0][0]']
#  ormalization)
#
#  batch_normalization_82 (BatchN  (None, 8, 8, 384)   1152        ['conv2d_87[0][0]']
#  ormalization)
#
#  batch_normalization_83 (BatchN  (None, 8, 8, 384)   1152        ['conv2d_88[0][0]']
#  ormalization)
#
#  conv2d_89 (Conv2D)             (None, 8, 8, 192)    245760      ['average_pooling2d_7[0][0]']
#
#  batch_normalization_76 (BatchN  (None, 8, 8, 320)   960         ['conv2d_81[0][0]']
#  ormalization)
#
#  activation_78 (Activation)     (None, 8, 8, 384)    0           ['batch_normalization_78[0][0]']
#
#  activation_79 (Activation)     (None, 8, 8, 384)    0           ['batch_normalization_79[0][0]']
#
#  activation_82 (Activation)     (None, 8, 8, 384)    0           ['batch_normalization_82[0][0]']
#
#  activation_83 (Activation)     (None, 8, 8, 384)    0           ['batch_normalization_83[0][0]']
#
#  batch_normalization_84 (BatchN  (None, 8, 8, 192)   576         ['conv2d_89[0][0]']
#  ormalization)
#
#  activation_76 (Activation)     (None, 8, 8, 320)    0           ['batch_normalization_76[0][0]']
#
#  mixed9_0 (Concatenate)         (None, 8, 8, 768)    0           ['activation_78[0][0]',
#                                                                   'activation_79[0][0]']
#
#  concatenate (Concatenate)      (None, 8, 8, 768)    0           ['activation_82[0][0]',
#                                                                   'activation_83[0][0]']
#
#  activation_84 (Activation)     (None, 8, 8, 192)    0           ['batch_normalization_84[0][0]']
#
#  mixed9 (Concatenate)           (None, 8, 8, 2048)   0           ['activation_76[0][0]',
#                                                                   'mixed9_0[0][0]',
#                                                                   'concatenate[0][0]',
#                                                                   'activation_84[0][0]']
#
#  conv2d_94 (Conv2D)             (None, 8, 8, 448)    917504      ['mixed9[0][0]']
#
#  batch_normalization_89 (BatchN  (None, 8, 8, 448)   1344        ['conv2d_94[0][0]']
#  ormalization)
#
#  activation_89 (Activation)     (None, 8, 8, 448)    0           ['batch_normalization_89[0][0]']
#
#  conv2d_91 (Conv2D)             (None, 8, 8, 384)    786432      ['mixed9[0][0]']
#
#  conv2d_95 (Conv2D)             (None, 8, 8, 384)    1548288     ['activation_89[0][0]']
#
#  batch_normalization_86 (BatchN  (None, 8, 8, 384)   1152        ['conv2d_91[0][0]']
#  ormalization)
#
#  batch_normalization_90 (BatchN  (None, 8, 8, 384)   1152        ['conv2d_95[0][0]']
#  ormalization)
#
#  activation_86 (Activation)     (None, 8, 8, 384)    0           ['batch_normalization_86[0][0]']
#
#  activation_90 (Activation)     (None, 8, 8, 384)    0           ['batch_normalization_90[0][0]']
#
#  conv2d_92 (Conv2D)             (None, 8, 8, 384)    442368      ['activation_86[0][0]']
#
#  conv2d_93 (Conv2D)             (None, 8, 8, 384)    442368      ['activation_86[0][0]']
#
#  conv2d_96 (Conv2D)             (None, 8, 8, 384)    442368      ['activation_90[0][0]']
#
#  conv2d_97 (Conv2D)             (None, 8, 8, 384)    442368      ['activation_90[0][0]']
#
#  average_pooling2d_8 (AveragePo  (None, 8, 8, 2048)  0           ['mixed9[0][0]']
#  oling2D)
#
#  conv2d_90 (Conv2D)             (None, 8, 8, 320)    655360      ['mixed9[0][0]']
#
#  batch_normalization_87 (BatchN  (None, 8, 8, 384)   1152        ['conv2d_92[0][0]']
#  ormalization)
#
#  batch_normalization_88 (BatchN  (None, 8, 8, 384)   1152        ['conv2d_93[0][0]']
#  ormalization)
#
#  batch_normalization_91 (BatchN  (None, 8, 8, 384)   1152        ['conv2d_96[0][0]']
#  ormalization)
#
#  batch_normalization_92 (BatchN  (None, 8, 8, 384)   1152        ['conv2d_97[0][0]']
#  ormalization)
#
#  conv2d_98 (Conv2D)             (None, 8, 8, 192)    393216      ['average_pooling2d_8[0][0]']
#
#  batch_normalization_85 (BatchN  (None, 8, 8, 320)   960         ['conv2d_90[0][0]']
#  ormalization)
#
#  activation_87 (Activation)     (None, 8, 8, 384)    0           ['batch_normalization_87[0][0]']
#
#  activation_88 (Activation)     (None, 8, 8, 384)    0           ['batch_normalization_88[0][0]']
#
#  activation_91 (Activation)     (None, 8, 8, 384)    0           ['batch_normalization_91[0][0]']
#
#  activation_92 (Activation)     (None, 8, 8, 384)    0           ['batch_normalization_92[0][0]']
#
#  batch_normalization_93 (BatchN  (None, 8, 8, 192)   576         ['conv2d_98[0][0]']
#  ormalization)
#
#  activation_85 (Activation)     (None, 8, 8, 320)    0           ['batch_normalization_85[0][0]']
#
#  mixed9_1 (Concatenate)         (None, 8, 8, 768)    0           ['activation_87[0][0]',
#                                                                   'activation_88[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 8, 8, 768)    0           ['activation_91[0][0]',
#                                                                   'activation_92[0][0]']
#
#  activation_93 (Activation)     (None, 8, 8, 192)    0           ['batch_normalization_93[0][0]']
#
#  mixed10 (Concatenate)          (None, 8, 8, 2048)   0           ['activation_85[0][0]',
#                                                                   'mixed9_1[0][0]',
#                                                                   'concatenate_1[0][0]',
#                                                                   'activation_93[0][0]']
#
# ==================================================================================================
# Total params: 21,802,784
# Trainable params: 21,768,352
# Non-trainable params: 34,432
# __________________________________________________________________________________________________

# %%
for layer in pretrained_model.layers:
  layer.trainable = False
stop_layer = pretrained_model.get_layer('mixed7')
x = Flatten()(stop_layer.output)
x = Dense(1024,activation='relu')(x)
x = Dense(1,activation='sigmoid')(x)

# %%
model2 = None
if (RETRAIN_model2 or (not os.path.exists('pretrained_best_model.h5'))):
  model2 = Model(pretrained_model.input,x)
  model2.compile(optimizer=RMSprop(learning_rate=0.0001),loss='binary_crossentropy',metrics=['acc'])
  model2.fit(train_generator,epochs=40,validation_data=validation_generator,callbacks=[early_stopping_callback,model_checkpoint_callback_pretrained])
else: 
  model2 = load_model('pretrained_best_model.h5')  
  print("pretrained_model loaded from memory!")
# Out:
# pretrained_model loaded from memory!

# %% [markdown]
# #### Testing images

# %%
test_dir_horse = './test_images/horse'
test_dir_human = './test_images/human'
print(train_generator.class_indices)
horse_image_files = [f for f in os.listdir(test_dir_horse) if f.endswith(('jpg', 'png','jpeg'))]
human_image_files = [f for f in os.listdir(test_dir_human) if f.endswith(('jpg', 'png','jpeg'))]
correct_pred_horses_model_1 = 0
correct_pred_horses_model_2 = 0
correct_pred_humans_model_1 = 0
correct_pred_humans_model_2 = 0

for img_file in horse_image_files:
    img_path = os.path.join(test_dir_horse, img_file)
    img = image.load_img(img_path, target_size=(300, 300))
    x = image.img_to_array(img)
    x = np.expand_dims(x, axis=0)
    image_tensor = np.vstack([x])
    classes = model.predict(image_tensor)
    classes2 = model2.predict(image_tensor)
    if classes[0] > 0.5:
        print(f"{model.name} - {img_file} is a human")
    else:
        print(f"{model.name} - {img_file} is a horse")
        correct_pred_horses_model_1 += 1
    
    if classes2[0] > 0.5:
        print(f"{model2.name} - {img_file} is a human")
    else:
        print(f"{model2.name} - {img_file} is a horse")
        correct_pred_horses_model_2 += 1
print(f"Accuracy of horses (custom CNN) = {float(correct_pred_humans_model_1)/len(horse_image_files)}")        
print(f"Accuracy of horses (pretrained model Inception V3) = {float(correct_pred_humans_model_2)/len(horse_image_files)}")        
 
for img_file in human_image_files:
    img_path = os.path.join(test_dir_human, img_file)
    img = image.load_img(img_path, target_size=(300, 300))
    x = image.img_to_array(img)
    x = np.expand_dims(x, axis=0)
    image_tensor = np.vstack([x])
    classes = model.predict(image_tensor)
    classes2 = model2.predict(image_tensor)
    if classes[0] > 0.5:
        print(f"{model.name} - {img_file} is a human")
        correct_pred_humans_model_1 += 1
    else:
        print(f"{model.name} - {img_file} is a horse")
    if classes2[0] > 0.5:
        print(f"{model2.name} - {img_file} is a human")
        correct_pred_humans_model_2 += 1  
    else:
        print(f"{model2.name} - {img_file} is a horse")   
print(f"Accuracy of humans (custom CNN) = {float(correct_pred_humans_model_1)/len(human_image_files)}")        
print(f"Accuracy of humans (pretrained model Inception V3) = {float(correct_pred_humans_model_2)/len(human_image_files)}")
# Out:
# {'horses': 0, 'humans': 1}
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 131ms/step
# sequential_2 - image-31.png is a horse
# model_3 - image-31.png is a human
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 100ms/step
# sequential_2 - image-25.png is a horse
# model_3 - image-25.png is a human
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 98ms/step
# sequential_2 - image-24.png is a horse
# model_3 - image-24.png is a human
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 102ms/step
# sequential_2 - image-30.png is a human
# model_3 - image-30.png is a human
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 101ms/step
# sequential_2 - image-26.png is a human
# model_3 - image-26.png is a human
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 106ms/step
# sequential_2 - image-32.png is a horse
# model_3 - image-32.png is a human
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 99ms/step
# sequential_2 - image-33.png is a horse
# model_3 - image-33.png is a human
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 112ms/step
# sequential_2 - image-27.png is a horse
# model_3 - image-27.png is a human
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 97ms/step
# sequential_2 - image-23.png is a horse
# model_3 - image-23.png is a human
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 97ms/step
# sequential_2 - image-37.png is a human
# model_3 - image-37.png is a human
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 94ms/step
# sequential_2 - image-36.png is a horse
# model_3 - image-36.png is a human
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 95ms/step
# sequential_2 - image-35.png is a horse
# model_3 - image-35.png is a human
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 95ms/step
# sequential_2 - image-29.png is a human
# model_3 - image-29.png is a human
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 96ms/step
# sequential_2 - image-28.png is a horse
# model_3 - image-28.png is a human
# Accuracy of horses (custom CNN) = 0.0
# Accuracy of horses (pretrained model Inception V3) = 0.0
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 98ms/step
# sequential_2 - download.jpeg is a human
# model_3 - download.jpeg is a human
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 112ms/step
# sequential_2 - image-8.jpg is a human
# model_3 - image-8.jpg is a human
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 102ms/step
# sequential_2 - photo-1438761681033-6461ffad8d80.jpeg is a horse
# model_3 - photo-1438761681033-6461ffad8d80.jpeg is a human
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 99ms/step
# sequential_2 - eea40c6ce4f241d6214f3f40943e6630.jpg is a horse
# model_3 - eea40c6ce4f241d6214f3f40943e6630.jpg is a human
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 98ms/step
# sequential_2 - download (3).jpeg is a human
# model_3 - download (3).jpeg is a human
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 94ms/step
# sequential_2 - download (1).jpeg is a human
# model_3 - download (1).jpeg is a human
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 133ms/step
# sequential_2 - download (4).jpeg is a human
# model_3 - download (4).jpeg is a human
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 96ms/step
# sequential_2 - download (2).jpeg is a human
# model_3 - download (2).jpeg is a human
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 95ms/step
# sequential_2 - v3_0188330.jpg is a human
# model_3 - v3_0188330.jpg is a human
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 96ms/step
# sequential_2 - image-1.jpg is a human
# model_3 - image-1.jpg is a human
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 101ms/step
# sequential_2 - image-3.jpg is a human
# model_3 - image-3.jpg is a human
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 95ms/step
# sequential_2 - image-7.jpg is a horse
# model_3 - image-7.jpg is a human
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 96ms/step
# sequential_2 - image-5.jpg is a human
# model_3 - image-5.jpg is a human
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 95ms/step
# sequential_2 - image-4.jpg is a horse
# model_3 - image-4.jpg is a human
# Accuracy of humans (custom CNN) = 0.7142857142857143
# Accuracy of humans (pretrained model Inception V3) = 1.0
